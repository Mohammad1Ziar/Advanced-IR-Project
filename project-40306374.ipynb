# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv('/kaggle/input/snappfood-persian-sentiment-analysis/Snappfood - Sentiment Analysis.csv'
                ,encoding='utf-8', sep='\t+', on_bad_lines='skip', engine='python')

# %%
df = df.head(70000)
df = df[['comment', 'label']]
df = df.dropna()

# %%
# !pip install hazm
# Out:
# Requirement already satisfied: hazm in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: fasttext-wheel<0.10.0,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from hazm) (0.9.2)
# Requirement already satisfied: flashtext<3.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from hazm) (2.7)
# Requirement already satisfied: gensim<5.0.0,>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (4.3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from hazm) (3.9.1)
# Requirement already satisfied: numpy==1.24.3 in /usr/local/lib/python3.10/dist-packages (from hazm) (1.24.3)
# Requirement already satisfied: python-crfsuite<0.10.0,>=0.9.9 in /usr/local/lib/python3.10/dist-packages (from hazm) (0.9.11)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.2 in /usr/local/lib/python3.10/dist-packages (from hazm) (1.2.2)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fasttext-wheel<0.10.0,>=0.9.2->hazm) (71.0.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.1->hazm) (7.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->hazm) (4.66.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.2->hazm) (3.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.1->hazm) (1.16.0)

# %%
from hazm import Normalizer

# نرمال‌سازی متن‌ها
normalizer = Normalizer()

def preprocess_text(text):
    # حذف فاصله‌های اضافی، تبدیل اعداد انگلیسی به فارسی، و نرمال‌سازی متن
    return normalizer.normalize(text)

# انجام پیش‌پردازش روی ستون کامنت
df['comment'] = df['comment'].apply(preprocess_text)

# بررسی نتیجه
print(df.head())

# data.to_csv("Snappfood-Sentiment Analysis_preprocessed.csv", index=False)
# print("preprocesing done & dataset saved")
# Out:
#                                              comment  label
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح    SAD
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...  HAPPY
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...    SAD
# 3  عالی بود همه چه درست و به اندازه و کیفیت خوب، ...  HAPPY
# 4                      شیرینی وانیلی فقط یک مدل بود.  HAPPY

# %%
def load_data(file_path, stop_words, encoding='utf-8', sep='\t+', on_bad_lines='skip', engine='python'):
    df = pd.read_csv(file_path, encoding=encoding, sep=sep, on_bad_lines=on_bad_lines, engine=engine)
    return df

# %%
#  استاپ ورد ها
stop_words = ["و", "به", "از", "که", "در", "چرا", "هم", "چه", "یا", "با", "تا", "نیز", "را", "پس", "چون", "ولی", "چه", "اگر", "اما", "زیرا", "بس", "ازبس"]

file_path = '/kaggle/input/snappfood-persian-sentiment-analysis/Snappfood - Sentiment Analysis.csv'  # مسیر جدید داده‌ها
data = load_data(file_path, stop_words=stop_words, encoding='utf-8', sep='\t+', on_bad_lines='skip', engine='python')

# %%
def preprocess_data(data, stop_words):
    def remove_stop_words(comment):
        return ' '.join([word for word in text.split() if word not in stop_words])

    data['comment'] = data['comment'].apply(remove_stop_words)
    return data

# %%
def map_labels(label):
    if label == "HAPPY":
        return 1
    else:
        return 0

df['label'] = df['label'].apply(map_labels)

# %%
print(df['label'].value_counts())
# Out:
# label
# 0    35000
# 1    35000
# Name: count, dtype: int64

# %%
df['comment_length'] = df['comment'].apply(len)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['comment_length'], bins=50, kde=True, color='blue')
plt.title('Distribution of Comment Lengths')
plt.xlabel('Comment Length')
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['comment_length'], color='orange')
plt.title('Boxplot of Comment Lengths')
plt.xlabel('Comment Length')
plt.show()

# %%
# محاسبه چارک‌ها
Q1 = df['comment_length'].quantile(0.25)
Q3 = df['comment_length'].quantile(0.75)
IQR = Q3 - Q1

# تعیین حد بالا و پایین
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Upper limit: {lower_bound}")
print(f"Lower limit: {upper_bound}")

# حذف داده‌های پرت
cleaned_df = df[(df['comment_length'] >= lower_bound) & (df['comment_length'] <= upper_bound)]
print(f"تعداد داده‌های باقی‌مانده: {cleaned_df.shape[0]}")
# Out:
# Upper limit: -73.5
# Lower limit: 226.5
# تعداد داده‌های باقی‌مانده: 66024

# %%
greater_than_226 = cleaned_df[cleaned_df['comment_length'] > 226].shape[0]

between_0_and_226 = cleaned_df[(cleaned_df['comment_length'] > 0) & (cleaned_df['comment_length'] <= 226)].shape[0]

print(f"تعداد داده‌هایی که طول متن آن‌ها بیشتر از 226 است: {greater_than_226}")
print(f"تعداد داده‌هایی که طول متن آن‌ها بین 0 تا 226 است: {between_0_and_226}")
# Out:
# تعداد داده‌هایی که طول متن آن‌ها بیشتر از 226 است: 0
# تعداد داده‌هایی که طول متن آن‌ها بین 0 تا 226 است: 66024

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(cleaned_df['comment_length'], bins=50, kde=True, color='green')
plt.title('Distribution of Comment Lengths (After Cleaning #1)')
plt.xlabel('Comment Length')
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# حذف داده های گمشده
cleaned_df = cleaned_df.dropna()

cleaned_df = cleaned_df.dropna(axis=1)

# %%
# شمارش داده‌های تکراری
print(f"تعداد داده‌های تکراری: {cleaned_df.duplicated().sum()}")

# حذف داده‌های تکراری
cleaned_df = cleaned_df.drop_duplicates()
# Out:
# تعداد داده‌های تکراری: 51

# %% [markdown]
# ## Number of duplicate data's removed: 51

# %%
import re

def clean_comment(comment):
    comment = re.sub(r'\s+', ' ', comment)  
    comment = re.sub(r'http\S+', '', comment)  
    comment = re.sub(r'[^\w\s]', '', comment)  
    comment = re.sub(r'\d+', '', comment)  
    return comment.strip()

cleaned_df['comment_cleaned'] = cleaned_df['comment'].apply(clean_comment)

# %%
output_path = '/kaggle/working/cleaned_data.csv'  # مسیر ذخیره‌سازی فایل
cleaned_df.to_csv(output_path, index=False, encoding='utf-8')

# %%
print(cleaned_df.head())
print(cleaned_df.columns)
# Out:
#                                              comment  label  comment_length  \
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح      0              47
# 1  قرار بود ۱ ساعته برسه ولی نیم ساعت زودتر از مو...      1             132
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره، فقط...      0              89
# 3  عالی بود همه چه درست و به اندازه و کیفیت خوب، ...      1              99
# 4                      شیرینی وانیلی فقط یک مدل بود.      1              29
#
#                                      comment_cleaned
# 0    واقعا حیف وقت که بنویسم سرویس دهیتون شده افتضاح
# 1  قرار بود  ساعته برسه ولی نیم ساعت زودتر از موق...
# 2  قیمت این مدل اصلا با کیفیتش سازگاری نداره فقط ...
# 3  عالی بود همه چه درست و به اندازه و کیفیت خوب ا...
# 4                       شیرینی وانیلی فقط یک مدل بود
# Index(['comment', 'label', 'comment_length', 'comment_cleaned'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(cleaned_df['comment_length'], bins=50, kde=True, color='green')
plt.title('Distribution of Comment Lengths (After Cleaning #2)')
plt.xlabel('Comment Length')
plt.ylabel('Frequency')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print(cleaned_df['label'].value_counts())
# Out:
# label
# 1    33675
# 0    32298
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer

# %%
# خواندن دیتاست تمیز شده
cleaned_df = pd.read_csv("cleaned_data.csv")  # فرض بر این است که دیتاست تمیز شده در فایل موجود است

# تقسیم داده‌ها به قسمت (اموش 50%، ولیدیشن 20%، تست 30%)
train_data, temp_data = train_test_split(cleaned_df, test_size=0.5, stratify=cleaned_df['label'], random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.6, stratify=temp_data['label'], random_state=42)

print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(val_data)}")
print(f"Test samples: {len(test_data)}")

# ذخیره داده‌های تقسیم شده
train_data.to_csv("snappfood_train.csv", index=False)
val_data.to_csv("snappfood_val.csv", index=False)
test_data.to_csv("snappfood_test.csv", index=False)

print("dataset is ready")

# لود کردن توکنایزر
tokenizer = AutoTokenizer.from_pretrained("HooshvareLab/bert-fa-base-uncased") 

train_encodings = tokenizer(list(train_data['comment']), truncation=True, padding=True, max_length=198)
val_encodings = tokenizer(list(val_data['comment']), truncation=True, padding=True, max_length=198)
test_encodings = tokenizer(list(test_data['comment']), truncation=True, padding=True, max_length=198)

train_labels = list(train_data['label'])
val_labels = list(val_data['label'])
test_labels = list(test_data['label'])

print("successfully done")
# Out:
# Training samples: 32986
# Validation samples: 13194
# Test samples: 19793
# dataset is ready
# config.json:   0%|          | 0.00/440 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.20M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# successfully done

# %%
'''
# لود داده‌های تقسیم‌شده
train_data = pd.read_csv("snappfood_train.csv")
val_data = pd.read_csv("snappfood_val.csv")
test_data = pd.read_csv("snappfood_test.csv")
'''
# Out:
# '\n# لود داده\u200cهای تقسیم\u200cشده\ntrain_data = pd.read_csv("snappfood_train.csv")\nval_data = pd.read_csv("snappfood_val.csv")\ntest_data = pd.read_csv("snappfood_test.csv")\n'

# %%
'''
# ذخیره داده‌های تقسیم‌شده
train_data.to_csv("snappfood_train.csv", index=False)
val_data.to_csv("snappfood_val.csv", index=False)
test_data.to_csv("snappfood_test.csv", index=False)

print("successfully done")
'''
# Out:
# '\n# ذخیره داده\u200cهای تقسیم\u200cشده\ntrain_data.to_csv("snappfood_train.csv", index=False)\nval_data.to_csv("snappfood_val.csv", index=False)\ntest_data.to_csv("snappfood_test.csv", index=False)\n\nprint("successfully done")\n'

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
from transformers import AutoModelForSequenceClassification
from torch.utils.data import DataLoader, Dataset
import torch
import pandas as pd

# %%
# بارگذاری مدل و توکنایزر پارس برت
MODEL_NAME = "HooshvareLab/bert-fa-base-uncased-sentiment-snappfood"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME, num_labels=2)

# تعریف کلاس دیتاست برای پای ترچ
class snappfoodDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, index):
        text = self.texts[index]
        label = self.labels[index]

        encoding = self.tokenizer(
            text,
            max_length=self.max_len,
            padding="max_length",
            truncation=True,
            return_tensors="pt",
        )

        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "labels": torch.tensor(label, dtype=torch.long),
        }
# Out:
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/621 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.20M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/651M [00:00<?, ?B/s]

# %%
# تعریف دیتاست‌ها
train_dataset = snappfoodDataset(
    texts=train_data["comment"].tolist(),
    labels=train_data["label"].tolist(),
    tokenizer=tokenizer,
    max_len=224,
)

val_dataset = snappfoodDataset(
    texts=val_data["comment"].tolist(),
    labels=val_data["label"].tolist(),
    tokenizer=tokenizer,
    max_len=224,
)

test_dataset = snappfoodDataset(
    texts=test_data["comment"].tolist(),
    labels=test_data["label"].tolist(),
    tokenizer=tokenizer,
    max_len=224,
)

# %%
batch_size = 16

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print("model and data are ready")
# Out:
# model and data are ready

# %%
# انتقال مدل به GPU در صورت وجود
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
import torch
import time
from torch.optim import AdamW
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from tqdm import tqdm
import torch.nn as nn

# %%
pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# بارگذاری مدل از Hugging Face
MODEL_NAME = "HooshvareLab/bert-fa-base-uncased-sentiment-snappfood"
base_model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME)

# %%
# افزودن Dropout و L2 Regularization
class CustomParsBERT(nn.Module):
    def __init__(self, model, dropout_prob=0.3, l2_lambda=0.01):
        super(CustomParsBERT, self).__init__()
        self.bert = model.bert
        self.dropout = nn.Dropout(p=dropout_prob)
        self.classifier = nn.Linear(model.config.hidden_size, model.config.num_labels)
        self.l2_lambda = l2_lambda

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = self.dropout(outputs.pooler_output)
        logits = self.classifier(pooled_output)

        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

            # افزودن L2 Regularization
            l2_reg = sum(param.norm(2) for param in self.classifier.parameters())
            loss += self.l2_lambda * l2_reg

            return loss, logits
        return logits

# %%
# تابع آموزش مدل
def train_model(learning_rate, batch_size):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = CustomParsBERT(base_model)  
    model.to(device)

    optimizer = AdamW(model.parameters(), lr=learning_rate)
    num_epochs = 10

    for epoch in range(num_epochs):
        torch.cuda.empty_cache()
        model.train()
        train_loss = 0
        train_preds, train_labels = [], []

        for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1}/{num_epochs}, LR={learning_rate}, BS={batch_size}"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            optimizer.zero_grad()
            loss, logits = model(input_ids, attention_mask, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            preds = torch.argmax(logits, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_labels.extend(labels.cpu().numpy())

        # ارزیابی مدل روی داده اعتبارسنجی
        model.eval()
        val_loss = 0
        val_preds, val_labels = [], []

        with torch.no_grad():
            for batch in val_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                loss, logits = model(input_ids, attention_mask, labels)
                val_loss += loss.item()
                preds = torch.argmax(logits, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_labels.extend(labels.cpu().numpy())

        val_accuracy = accuracy_score(val_labels, val_preds)
        print(f"Epoch {epoch + 1}: Validation Accuracy: {val_accuracy:.4f}")

    return model, val_accuracy
    

# تنظیم هایپرپارامترها
learning_rates = [1e-6]
batch_sizes = [8]


final_accuracy = 0
final_model = None
final_params = {}

for lr in learning_rates:
    for batch_size in batch_sizes:
        print(f"Training with lr={lr}, batch_size={batch_size}")
        model, val_accuracy = train_model(lr, batch_size)

        if val_accuracy > final_accuracy:
            final_accuracy = val_accuracy
            final_model = model
            final_params = {'learning_rate': lr, 'batch_size': batch_size}

print(f"final Accuracy: {final_accuracy}")
print(f"final Params: {final_params}")

# save final model
torch.save(final_model.state_dict(), 'final_model.pth')
print("final model saved as 'final_model.pth'")
# Out:
# Training with lr=1e-06, batch_size=8
# Epoch 1/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:02<00:00,  2.63it/s]
# Epoch 1: Validation Accuracy: 0.9296
# Epoch 2/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:06<00:00,  2.62it/s]
# Epoch 2: Validation Accuracy: 0.9307
# Epoch 3/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:07<00:00,  2.62it/s]
# Epoch 3: Validation Accuracy: 0.9315
# Epoch 4/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:08<00:00,  2.62it/s]
# Epoch 4: Validation Accuracy: 0.9308
# Epoch 5/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:07<00:00,  2.62it/s]
# Epoch 5: Validation Accuracy: 0.9290
# Epoch 6/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:07<00:00,  2.62it/s]
# Epoch 6: Validation Accuracy: 0.9285
# Epoch 7/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:07<00:00,  2.62it/s]
# Epoch 7: Validation Accuracy: 0.9282
# Epoch 8/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:07<00:00,  2.62it/s]
# Epoch 8: Validation Accuracy: 0.9272
# Epoch 9/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:07<00:00,  2.62it/s]
# Epoch 9: Validation Accuracy: 0.9278
# Epoch 10/10, LR=1e-06, BS=8: 100%|██████████| 2062/2062 [13:07<00:00,  2.62it/s]
# Epoch 10: Validation Accuracy: 0.9273
# final Accuracy: 0.9273154464150372
# final Params: {'learning_rate': 1e-06, 'batch_size': 8}
# final model saved as 'final_model.pth'

# %%
model.load_state_dict(torch.load('final_model.pth'))
model.to(device)
# Out:
# <ipython-input-39-13dd4b53af5f>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('final_model.pth'))
# CustomParsBERT(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(100000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.3, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
batch = next(iter(train_loader))  
input_ids = batch['input_ids'].to(device)
attention_mask = batch['attention_mask'].to(device)

# استفاده از مدل برای پیش‌بینی
logits = model(input_ids, attention_mask, labels=None)
preds = torch.argmax(logits, dim=1).cpu().numpy()

# %%
from sklearn.metrics import classification_report

# %%
def evaluate_model(model, dataloader, device):
    model.eval()
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Evaluating Model"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask)
            logits = model(input_ids, attention_mask)

            preds = torch.argmax(logits, dim=1).cpu().numpy()
            all_preds.extend(preds)
            all_labels.extend(labels.cpu().numpy())

    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')

    # نمایش نتایج
    print("Test Results:")
    print(f"  Accuracy: {accuracy:.4f}")
    print(f"  Precision: {precision:.4f}")
    print(f"  Recall: {recall:.4f}")
    print(f"  F1-Score: {f1:.4f}")
    print("\\nClassification Report:")
    print(classification_report(all_labels, all_preds, digits=4))

model.load_state_dict(torch.load('final_model.pth'))
model.to(device)

evaluate_model(model, test_loader, device)
# Out:
# <ipython-input-42-ef907e1f147c>:32: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('final_model.pth'))
# Evaluating Model: 100%|██████████| 1238/1238 [04:23<00:00,  4.71it/s]
# Test Results:
#   Accuracy: 0.9248
#   Precision: 0.9252
#   Recall: 0.9248
#   F1-Score: 0.9248
# \nClassification Report:
#               precision    recall  f1-score   support
#
#            0     0.9112    0.9379    0.9243      9690
#            1     0.9387    0.9123    0.9253     10103
#
#     accuracy                         0.9248     19793
#    macro avg     0.9249    0.9251    0.9248     19793
# weighted avg     0.9252    0.9248    0.9248     19793

# %%
from sklearn.metrics import roc_curve, auc

# test function for ROC
def evaluate_roc_curve(model, dataloader, device):
    model.eval()
    all_probs, all_labels = [], []

    with torch.no_grad():
        for batch in tqdm(dataloader):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            logits = model(input_ids, attention_mask, labels=None)  
            probs = torch.softmax(logits, dim=1)[:, 1].cpu().numpy()  
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())

    # calculate FPR، TPR و AUC
    fpr, tpr, thresholds = roc_curve(all_labels, all_probs)
    roc_auc = auc(fpr, tpr)

    # print ROC
    plt.figure()
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
    plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--', label='Random Guess')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.grid()
    plt.show()

# test model & print ROC
print("Plotting ROC curve...")
evaluate_roc_curve(model, test_loader, device)
# Out:
# Plotting ROC curve...
# 100%|██████████| 1238/1238 [02:16<00:00,  9.08it/s]

# %%
val_texts = val_dataset.texts  
val_labels = val_dataset.labels  

for batch in val_loader:
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    
    # دریافت logits از مدل
    logits = final_model(input_ids, attention_mask)

    # محاسبه پیش‌بینی‌ها
    val_predictions = logits.argmax(axis=1)

    # استخراج خطاها
    errors = [text for text, pred, label in zip(val_texts, val_predictions, val_labels) if pred != label]
    print("\nErrors:")
    print(errors)
# Out:
# Errors:
# []
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'بسیار عذا عالی و لذیذ بود']
#
# Errors:
# ['بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['کیفیت خیلی خوب و داغ بود. ممنون', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی']
#
# Errors:
# ['بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['خیلی خوب بود: -)', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'کیفیت خیلی خوب و داغ بود. ممنون', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی']
#
# Errors:
# ['بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی خوب بود: -)', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['خیلی خوب بود: -)', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی خوب بود: -)', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بسیار عذا عالی و لذیذ بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بسیار عذا عالی و لذیذ بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ...
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'بسیار عذا عالی و لذیذ بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی']
#
# Errors:
# ['کیفیت خیلی خوب و داغ بود. ممنون', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'بسیار عذا عالی و لذیذ بود', 'ممنون همه چی خوب بود', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['خیلی خوب بود: -)', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بسیار عذا عالی و لذیذ بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'افتضاح مقداری پنیر پیتزا و خمیر نون که خوب بود با قاشق بخوری اصلا نمی\u200cشد یه تکه پیتزا برداشت هروقت تو این محدوده پیتزا سفارش دادم پشیمون شدم هیچ کدوم کیفیت ندارن', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'بسیار عالی-باتشکر از دومینوز و اسنپ فود', 'بسیار عذا عالی و لذیذ بود', 'برای دومین بار سفارشم با تاخیر خیلی زیاد رسید. دیگه ترجیح میدم از اینجا سفارش ندم.', 'ممنون همه چی خوب بود', 'زمان پخت و تحویل خیلی زیاد اعلام می\u200cشود خیلی', 'آقا لطفا روی سیب\u200cزمینی سس نریز، انقد ریخته بودی از تو ظرف ریخته بود بیرون کل کیسه سسی شده بود، اگه علاقه به سس داری تو یه ظرف جدا بریز', 'من راضی اسلامی راضی دیگه چی بخوام']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'انقدر زود به دستم رسید، حتی زودتر از اس\u200cام اس اسنپ فود']
#
# Errors:
# ['من نوشابه شیشه\u200cای اسپرایت سفارش دادم که قیمتش هم بالاتره ولی نوشابه بطری\u200cای پلاستیکی فرستادن، یعنی پولش رو گرفته سوپرمارکت اما یه چیز دیگه که ارزونتره فرستاده، شما همین عدد رو ضرب در ۱۰۰۰ بکنید ببینید چقدر میشه؟!!!!', 'بنری و پیتزای که سفارش داده بودیم بندریش که فقط فقط سوسی داش پتیزاش خیلی بد مزه و ب یکیفت بود', 'خیلی عالی، سریع، تمیز، طعم عالی، بسته بندی عالی تعجب کردم که با این مبلغ برای دیزی همه مخلفات هم همراهش بود پیشنهاد می\u200cکنم بدون شک یکبار امتحان کنید', 'خیلی خوب بود: -)', 'پیک، سفارش را تا درب منزل نیاورد و غذا کاملا سرد بود. کیفیت پیتزا هم کمتر از همیشه بود، جمعا از سیب راضی هستم اما از بین سفارشات گاهی یک سفارش باعث عدم تمایل من به خرید دوباره می\u200cشود. لطفا تذکر زیادی داده بشه به همه سیب\u200cها', 'کیفیت خیلی خوب و داغ بود. ممنون', 'بادوم زمینی\u200cکه سفارش دادم ۴ هزار تومن قیمت داشت و ۷۰ گرمی چیزی که فرستادید ۲ هزار تومنی بود و وزن نصف، برام عجیبه چرا هیچ وقت برعکش اتفاق نمی\u200cافته لطفا دقت کنید در\u200cارسال']

# %%
incorrect_predictions_by_class = {}

for batch in val_loader:
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    
    logits = final_model(input_ids, attention_mask)

    val_predictions = logits.argmax(axis=1)

    for pred, label in zip(val_predictions, val_labels):
        if pred != label:
            if label not in incorrect_predictions_by_class:
                incorrect_predictions_by_class[label] = 0
            incorrect_predictions_by_class[label] += 1  

for class_label, error_count in incorrect_predictions_by_class.items():
    print(f"Class {class_label} - Misclassified samples count: {error_count}")
# Out:
# Class 0 - Misclassified samples count: 2921
# Class 1 - Misclassified samples count: 3737

# %% [markdown]
# ### The number of misclassified data's from both classes is 6658.
